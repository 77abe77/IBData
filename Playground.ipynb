# %%
from datetime import datetime, timedelta
from ibapi import wrapper
from ibapi import utils
from ibapi.client import EClient
from ibapi.utils import iswrapper
from ibapi.contract import *  
from ibapi.common import *
from ibapi.ticktype import * 
import threading
from app.wsgi import app
from app.extensions import db
from app.models.Equity import (
    Equity,
    EquityHistoricalData
)

# NOTE: Hist vol seems to not be able to be fetched day of
dataTypes = ["TRADES", "OPTION_IMPLIED_VOLATILITY", "HISTORICAL_VOLATILITY"] # ["TRADES", "MIDPOINT", "BID", "ASK", "HISTORICAL_VOLATILITY", "OPTION_IMPLIED_VOLATILITY"]
optionDataTypes = ["TRADES", "MIDPOINT", "BID", "ASK"]

dataTypeDuplicateDateSetMap = { dt: set() for dt in dataTypes}

failed_options_req = 0
optionsReqIdScheduledDataMap = {}
optionsReqIdDataMap = {}

reqIdScheduledDataMap = {}
reqIdDataMap = {}
failedRequests = 0

connectivityErrorCodes = [1100, 1300]
clientErrorCodes = [502, 504]
warningErrorCodes = [2100, 2137]
rateLimitErrorCodes = [100, 101]
twsErrorCodes = [102, 449]
twsErrorCodes2 = [10000, 10148]


# Global vars that would be set via the command line
day = "20200515"


reqIds = {}
    
class IBHistoricalDataAggregator(wrapper.EWrapper):
    
    def historicalData(self, reqId:int, bar: BarData):
        super().historicalData(reqId, bar)
        requestProcessor.updateRequest(reqId, bar)
#         if reqId not in reqIds:
    
        reqIds[reqId] = 0
        
        
            
        
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        requestProcessor.finishedRequest(reqId)
        
        if len(reqIds) + requestProcessor.failedRequests == len(requestProcessor.allReqsMap):
            ibapi.disconnect()
#         print("historicalDataEnd. reqId: ", reqId, "start: ", start, "end: ", end)
        
    
    def tickPrice(self, reqId: TickerId, tickType: TickType, price: float, attrib: TickAttrib):
        super().tickPrice(reqId, tickType, price, attrib)
        print("TickPrice. TickerId:", reqId, "tickType:", tickType,
            "Price:", price, "CanAutoExecute:", attrib.canAutoExecute,
            "PastLimit:", attrib.pastLimit, end=' ')
        if tickType == TickTypeEnum.BID or tickType == TickTypeEnum.ASK:
            print("PreOpen:", attrib.preOpen)
        else:
            print()
            
    def tickSize(self, reqId: TickerId, tickType: TickType, size: int):
        super().tickSize(reqId, tickType, size)
        print("TickSize. TickerId:", reqId, "TickType:", tickType, "Size:", size)
        
    
    def tickString(self, reqId: TickerId, tickType: TickType, value: str):
        super().tickString(reqId, tickType, value)
        print("TickString. TickerId:", reqId, "Type:", tickType, "Value:", value)
        
    def tickGeneric(self, reqId: TickerId, tickType: TickType, value: float):
        super().tickGeneric(reqId, tickType, value)
        print("TickGeneric. TickerId:", reqId, "TickType:", tickType, "Value:", value)
                
    def error(self, reqId: TickerId, errorCode: int, errorString: str):
        global failedRequests
        global failed_options_req
        super().error(reqId, errorCode, errorString)
        
        if reqId == -1:
            if errorCode >= rateLimitErrorCodes[0] and errorCode <= rateLimitErrorCodes[1]:
                print("RATE LIMIT ERROR")
                # TODO: Hope it doesnt happen
            print("WARNING: ", errorString)
            return
        elif errorCode >= twsErrorCodes[0] and errorCode <= twsErrorCodes[1] or errorCode >= twsErrorCodes2[0] and errorCode <= twsErrorCodes2[1]:
            print("TWS ERROR: ", errorString)
            # Decrement Expected Results Count
            if reqId > len(optionsReqIdScheduledDataMap.keys()):
                requestProcessor.failedRequest(reqId, errorString)
#                 failedRequests += 1
            else:  
                failed_options_req += 1
            
        elif errorCode >= rateLimitErrorCodes[0] and errorCode <= rateLimitErrorCodes[1]:
            print("RATE LIMIT ERROR")
            
    def securityDefinitionOptionParameter(self, reqId:int, exchange:str, underlyingConId:int, tradingClass:str, multiplier:str, expirations:SetOfString, strikes:SetOfFloat):
        super().securityDefinitionOptionParameter(reqId, exchange, underlyingConId, tradingClass, multiplier, expirations, strikes)
        global options_strikes
        global options_exp
        
        if exchange == "SMART":
            optionsReqDataMap[reqId] = {
                "expiration": expirations,
                "strike": strikes,                
            }
        else:
            failed_options_req += 1
            
        if len(optionsReqDataMap.keys()) == (len(optionsReqIdScheduledDataMap.keys()) - failed_options_req):
            # schedule options
            curReqId = len(reqIdScheduledDataMap.keys()) + len(optionsReqIdScheduledDataMap.keys())
            for key, val in optionsReqIdDataMap.items():
                for exp in val["expiration"]:
                    for strike in val["strike"]:     
                        pContract = Contract()
                        pContract.conId = optionsReqIdScheduledDataMap[key].conId
                        pContract.symbol = optionsReqIdScheduledDataMap[key].symbol
                        pContract.currency = optionsReqIdScheduledDataMap[key].currency
                        pContract.exchange = optionsReqIdScheduledDataMap[key].exchange
                        pContract.secType = "OPT"
                        pContract.lastTradeDateOrContractMonth = exp
                        pContract.strike = strike
                        pContract.right = "P"
                        
                        cContract = Contract()
                        cContract.conId = optionsReqIdScheduledDataMap[key].conId
                        cContract.symbol = optionsReqIdScheduledDataMap[key].symbol
                        cContract.currency = optionsReqIdScheduledDataMap[key].currency
                        cContract.exchange = optionsReqIdScheduledDataMap[key].exchange
                        cContract.secType = "OPT"
                        cContract.lastTradeDateOrContractMonth = exp
                        cContract.strike = strike
                        cContract.right = "C"
                        
                        for dataType in optionDataTypes:
                            scheduleIBHistoricalAPI(curReqId, cContract, endDateStr, "1 D", "1 min", dataType, 0)
                            curReqId += 1
                            scheduleIBHistoricalAPI(curReqId, pContract, endDateStr, "1 D", "1 min", dataType, 0)
                            curReqId += 1
                            
            # Start requesting
            processRequests()
        
    def nextValidId(self, reqId: int):
        super().nextValidId(reqId)
        print("Next Valid Id: ", reqId)
        
    def connectionClosed(self):
        super().connectionClosed()
    
batch_size = 50
granular_timeout = 600
regular_timeout = 1.2

granular_deffered_req = []
deffered_req = []
        
def scheduleIBHistoricalAPI(reqId, contract, endDateStr, durationStr, intervalStr, dataType, useRTH):
    def_req = {
        "reqId": reqId,
        "contract": contract,
        "endDateStr": endDateStr,
        "durationStr": durationStr,
        "intervalStr": intervalStr,
        "dataType": dataType,
        "useRTH": useRTH
    }
    
    reqIdScheduledDataMap[reqId] = def_req
    if intervalStr == "1 secs":
        requestProcessor.addGranularRequest(reqId, def_req)
#         granular_deffered_req.append(def_req)
    else:
        requestProcessor.addRegularRequest(reqId, def_req)
#         deffered_req.append(def_req)
    
class HistoricalRequestProcessor():
    # TODO: Add granular limit logic
    # Data Limit requirements
    # No more than 50 historical data req open at the same time
    # No more than 50 calls per sec
    # Granular:
    # Identical hist req within 15sec (we shouldnt see this?)
    # Making 6+ hist req for same contract, exch, and Historical Data Types within 2 sec (is tick type Historical Data Types)
    # Making more that 60 req within 10 min
    MAX_ACTIVE_REQ = 50
    MAX_REQ_PER_SEC = 50
    def __init__(self):
        self.non_granular_requests = []
        self.granular_requests = []
        self.activeRequests = 0
        self.failedRequests = 0
        self.startIdx = 0
        self.reqIdDataMap = {}
        self.allReqsMap = {}
        
    def addGranularRequest(self, reqId, req):
        self.granular_requests.append(req)
        self.allReqsMap[reqId] = req
    
    def addRegularRequest(self, reqId, req):
        self.non_granular_requests.append(req)
        self.allReqsMap[reqId] = req
        
    def run_non_granular_batch(self):
        for i in range(self.startIdx, min(self.startIdx + 50, len(self.non_granular_requests))):
            req = self.non_granular_requests[i]
            print("Running Request: ", req["reqId"])
            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
            self.activeRequests += 1
        self.startIdx = min(self.startIdx + 50, len(self.non_granular_requests)) - 1
        
        if self.startIdx == len(self.non_granular_requests):
            self.completion()
            
    def completion(self):
        print(datetime.now(), "HistoricalRequestProcessor: completion")
#         ibapi.disconnect()
        
    def process(self):
        self.run_non_granular_batch() 
        
    def updateRequest(self, reqId, bar):
        if reqId not in self.reqIdDataMap:
            self.reqIdDataMap[reqId] = []
        
        reqDT = self.allReqsMap[reqId]["dataType"]
#         if bar.date not in dataTypeDuplicateDateSetMap[reqDT]:
        self.reqIdDataMap[reqId].append({
            "date": bar.date,#datetime.strptime(bar.date, "%Y%m%d %H:%M:%S"),
            "open": bar.open,
            "high": bar.high,
            "low": bar.low,
            "close": bar.close,
            "volume": bar.volume,
            "barCount": bar.barCount,
            "average": bar.average,
        })
#             dataTypeDuplicateDateSetMap[reqDT].add(bar.date)
        
    def failedRequest(self, reqId, msg):
        print(datetime.now(), " HistoricalRequestProcessor: failedReqeust. ReqId: ", reqId, ": ", msg)
        self.failedRequests += 1
        if self.startIdx < len(self.non_granular_requests) - 1:
            self.startIdx += 1
            req = self.non_granular_requests[self.startIdx]
            print("Running Request: ", req["reqId"])
            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
        else:
            self.completion()
            
    def finishedRequest(self, reqId):
        self.activeRequests -= 1
        print(datetime.now(), " HistoricalRequestProcessor: finishedRequest: ", reqId)
        print("Progress: ", self.startIdx / len(self.non_granular_requests))
        if self.startIdx < len(self.non_granular_requests) - 1:
            self.startIdx += 1
            req = self.non_granular_requests[self.startIdx]
            print("Running Request: ", req["reqId"])
            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
        else:
            self.completion()
            

"""
    
    day: Precision of only a day: yyyyMMdd
"""
def getDayEquityInfo(contract, day, granular):
    curRequestID = len(optionsReqIdScheduledDataMap.keys()) + len(reqIdScheduledDataMap.keys())
    timeIntervals = []
    if type(granular) is bool and granular:
        endRTH = datetime.strptime('{} 13:00:00'.format(day), "%Y%m%d %H:%M:%S")
        beginRTH = datetime.strptime('{} 6:30:00'.format(day), "%Y%m%d %H:%M:%S")
   
        curEndTime = endRTH
        while curEndTime > beginRTH:
            timeIntervals.append({
                "endTimeStr": "{} PST".format(curEndTime.strftime("%Y%m%d %H:%M:%S")),
                "durationStr": "1800 S",
                "intervalStr": "1 secs"
            })
            
            curEndTime = curEndTime - timedelta(minutes=30)
        # Premarket
        timeIntervals.append({
            "endTimeStr": "{} 06:29:59 PST".format(day),
            "durationStr": "19740 S",
            "intervalStr": "1 min"
        })
        # After Market
        timeIntervals.append({
            "endTimeStr": "{} 17:00:00 PST".format(day),
            "durationStr": "14400 S",
            "intervalStr": "1 min"
        })
    else:
        timeIntervals.append({
            "endTimeStr": "{} 23:59:59 PST".format(day),
            "durationStr": "1 D",
            "intervalStr": granular if type(granular) is str else "1 min"
        })
                
#         timeIntervals.append({
#             "endTimeStr": "{} 23:59:59 PST".format(day),
#             "durationStr": "1 D",
#             "intervalStr": "1 min"
#         })
        
    for dt in dataTypes:
        if dt == "HISTORICAL_VOLATILITY":
            timeInterval = {
                    "endTimeStr": "{} 23:59:59 PST".format(day),
                    "durationStr": "1 D",
                    "intervalStr": granular if type(granular) is str and barSizeOrder[granular] > barSizeOrder["3 hours"] else "3 hours"
            }
            scheduleIBHistoricalAPI(curRequestID, contract, timeInterval["endTimeStr"], timeInterval["durationStr"], timeInterval["intervalStr"], dt, 0)
            curRequestID += 1
        else:
            for ti in timeIntervals:
                scheduleIBHistoricalAPI(curRequestID, contract, ti["endTimeStr"], ti["durationStr"], ti["intervalStr"], dt, 0)
                curRequestID += 1

barSizeOrder = { "1 secs": 0, "5 secs": 1, "10 secs": 2, "15 secs": 3, "30 secs": 4, "1 min": 5, "2 mins": 6, "3 mins": 7, "5 mins": 8, "10 mins": 9, "15 mins": 10, "20 min":11, "30 mins": 12, "1 hour": 13, "2 hours": 14, "3 hours": 15, "4 hours": 16, "8 hours": 17, "1 day": 18, "1 week": 19, "1 month": 20}
      
# def startScdsheduling(include_options, day):
#     options = []
#     with app.app_context():
#         # Yes doing a double loop is less effiecient than doin it all in one, but its simplier
#         def equityToContract(equity):
#             contract = Contract()
#             contract.symbol = equity.ticker
#             contract.secType = "STK"
#             contract.exchange = "SMART"
#             contract.currency = "USD"
#             contract.conId = equity.ib_con_id
#             return contract
        
#         if include_options:
#             optionsReqId = 0
            
                
#             options = [equity for equity in db.session.query(Equity).all() if equity.include_options]
#             options = map(equityToContract, options)
            
#             for op in options:
#                 optionsReqIdScheduledDataMap[optionsReqId] = op
#                 ibapi.reqSecDefOptParams(optionsReqId, op.symbol, "", "STK", op.conId)
#                 optionsReqId += 1
                
#         for equity in db.session.query(Equity).all():
#                 contract = equityToContract(equity)
#                 getDayEquityInfo(contract, day, equity.granular)
        
#         if not include_options:
#             processRequests()
            
            
def scheduleSPYData():
    contract = Contract()
    contract.symbol = "SPY"
    contract.secType = "STK"
    contract.exchange = "SMART"
    contract.currency = "USD"
    startDate = datetime.strptime("20190430", "%Y%m%d")
    endDate = datetime.strptime('20190812', "%Y%m%d")

    curTime = endDate
    while curTime >= startDate:
        if curTime.weekday() < 5:
            getDayEquityInfo(contract, curTime.strftime("%Y%m%d"), "4 hours")
        curTime = curTime - timedelta(days=1)
        
def scheduleVIXData():
    contract = Contract()
    contract.symbol = "VIX"
    contract.secType = "IND"
    contract.exchange = "CBOE"
    contract.currency = "USD"
    startDate = datetime.strptime("20191007", "%Y%m%d")
    endDate = datetime.strptime('20191209', "%Y%m%d")

    curTime = endDate
    while curTime >= startDate:
        if curTime.weekday() < 5:
            getDayEquityInfo(contract, curTime.strftime("%Y%m%d"), "4 hours")
        curTime = curTime - timedelta(days=1)
        

class ThreadedIBApi(EClient, threading.Thread):
    def __init__(self, wrapper):
        threading.Thread.__init__(self)
        EClient.__init__(self, wrapper=wrapper)           
        
requestProcessor = HistoricalRequestProcessor()
histDataAgregator = IBHistoricalDataAggregator()   
ibapi = ThreadedIBApi(wrapper=histDataAgregator)
gatewayPort = 4001
twsPort = 7496
ibapi.connect("host.docker.internal", gatewayPort, clientId=0)
ibapi.start()
# Out:
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# Next Valid Id:  1
# WARNING:  Market data farm connection is OK:usfarm.nj

# %%
ibapi.disconnect()
# Out:
# unhandled exception in EReader thread
# Traceback (most recent call last):
#   File "/venv/lib/python3.6/site-packages/ibapi/reader.py", line 34, in run
#     data = self.conn.recvMsg()
#   File "/venv/lib/python3.6/site-packages/ibapi/connection.py", line 99, in recvMsg
#     buf = self._recvAllMsg()
#   File "/venv/lib/python3.6/site-packages/ibapi/connection.py", line 119, in _recvAllMsg
#     buf = self.socket.recv(4096)
# OSError: [Errno 9] Bad file descriptor

# %%
scheduleSPYData()

# %%
requestProcessor.process()
# Out:
# Running Request:  0
# Running Request:  1
# Running Request:  2
# Running Request:  3
# Running Request:  4
# Running Request:  5
# Running Request:  6
# Running Request:  7
# Running Request:  8
# Running Request:  9
# Running Request:  10
# Running Request:  11
# Running Request:  12
# Running Request:  13
# Running Request:  14
# Running Request:  15
# Running Request:  16
# Running Request:  17
# Running Request:  18
# Running Request:  19
# Running Request:  20
# Running Request:  21
# Running Request:  22
# Running Request:  23
# Running Request:  24
# Running Request:  25
# Running Request:  26
# Running Request:  27
# Running Request:  28
# Running Request:  29
# Running Request:  30
# Running Request:  31
# Running Request:  32
# Running Request:  33
# Running Request:  34
# Running Request:  35
# Running Request:  36
# Running Request:  37
# Running Request:  38
# Running Request:  39
# Running Request:  40
# Running Request:  41
# Running Request:  42
# Running Request:  43
# Running Request:  44
# Running Request:  45
# Running Request:  46
# Running Request:  47
# Running Request:  48
# Running Request:  49
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# WARNING:  HMDS data farm connection is OK:ushmds
# 2020-07-20 04:31:28.620722  HistoricalRequestProcessor: finishedRequest:  30
# Progress:  0.21777777777777776
# Running Request:  50
# 2020-07-20 04:31:28.639921  HistoricalRequestProcessor: finishedRequest:  32
# Progress:  0.2222222222222222
# Running Request:  51
# 2020-07-20 04:31:28.644575  HistoricalRequestProcessor: finishedRequest:  31
# Progress:  0.22666666666666666
# Running Request:  52
# 2020-07-20 04:31:28.651657  HistoricalRequestProcessor: finishedRequest:  34
# Progress:  0.2311111111111111
# Running Request:  53
# 2020-07-20 04:31:28.655798  HistoricalRequestProcessor: finishedRequest:  35
# Progress:  0.23555555555555555
# Running Request:  54
# 2020-07-20 04:31:28.662849  HistoricalRequestProcessor: finishedRequest:  2
# Progress:  0.24
# Running Request:  55
# 2020-07-20 04:31:28.668766  HistoricalRequestProcessor: finishedRequest:  38
# Progress:  0.24444444444444444
# Running Request:  56
# 2020-07-20 04:31:28.684608  HistoricalRequestProcessor: finishedRequest:  37
# Progress:  0.24888888888888888
# Running Request:  57
# 2020-07-20 04:31:34.557423  HistoricalRequestProcessor: finishedRequest:  3
# Progress:  0.25333333333333335
# Running Request:  58
# 2020-07-20 04:31:34.563142  HistoricalRequestProcessor: finishedRequest:  24
# Progress:  0.2577777777777778
# Running Request:  59
# 2020-07-20 04:31:34.570086  HistoricalRequestProcessor: finishedRequest:  33
# Progress:  0.26222222222222225
# Running Request:  60
# 2020-07-20 04:31:34.574300  HistoricalRequestProcessor: finishedRequest:  15
# Progress:  0.26666666666666666
# Running Request:  61
# 2020-07-20 04:31:40.564723  HistoricalRequestProcessor: finishedRequest:  45
# Progress:  0.27111111111111114
# Running Request:  62
# 2020-07-20 04:31:40.579144  HistoricalRequestProcessor: finishedRequest:  29
# Progress:  0.27555555555555555
# Running Request:  63
# 2020-07-20 04:31:40.581756  HistoricalRequestProcessor: finishedRequest:  17
# Progress:  0.28
# Running Request:  64
# 2020-07-20 04:31:40.605398  HistoricalRequestProcessor: finishedRequest:  43
# Progress:  0.28444444444444444
# Running Request:  65
# 2020-07-20 04:31:46.571232  HistoricalRequestProcessor: finishedRequest:  48
# Progress:  0.28888888888888886
# Running Request:  66
# 2020-07-20 04:31:46.585573  HistoricalRequestProcessor: finishedRequest:  58
# Progress:  0.29333333333333333
# Running Request:  67
# 2020-07-20 04:31:46.588878  HistoricalRequestProcessor: finishedRequest:  59
# Progress:  0.29777777777777775
# Running Request:  68
# 2020-07-20 04:31:52.651314  HistoricalRequestProcessor: finishedRequest:  60
# Progress:  0.3022222222222222
# Running Request:  69
# 2020-07-20 04:31:52.654785  HistoricalRequestProcessor: finishedRequest:  63
# Progress:  0.30666666666666664
# Running Request:  70
# 2020-07-20 04:31:58.607508  HistoricalRequestProcessor: finishedRequest:  68
# Progress:  0.3111111111111111
# Running Request:  71
# 2020-07-20 04:32:04.572526  HistoricalRequestProcessor: finishedRequest:  4
# Progress:  0.31555555555555553
# Running Request:  72
# 2020-07-20 04:32:10.565380  HistoricalRequestProcessor: finishedRequest:  27
# Progress:  0.32
# Running Request:  73
# 2020-07-20 04:32:16.611015  HistoricalRequestProcessor: finishedRequest:  72
# Progress:  0.3244444444444444
# Running Request:  74
# 2020-07-20 04:32:28.584736  HistoricalRequestProcessor: finishedRequest:  69
# Progress:  0.3288888888888889
# Running Request:  75
# 2020-07-20 04:32:28.589427  HistoricalRequestProcessor: finishedRequest:  66
# Progress:  0.3333333333333333
# Running Request:  76
# 2020-07-20 04:32:28.593273  HistoricalRequestProcessor: finishedRequest:  6
# Progress:  0.3377777777777778
# Running Request:  77
# 2020-07-20 04:32:28.598353  HistoricalRequestProcessor: finishedRequest:  71
# Progress:  0.3422222222222222
# Running Request:  78
# 2020-07-20 04:32:28.601520  HistoricalRequestProcessor: finishedRequest:  14
# Progress:  0.3466666666666667
# Running Request:  79
# 2020-07-20 04:32:28.615307  HistoricalRequestProcessor: finishedRequest:  13
# Progress:  0.3511111111111111
# Running Request:  80
# 2020-07-20 04:32:28.618332  HistoricalRequestProcessor: finishedRequest:  41
# Progress:  0.35555555555555557
# Running Request:  81
# 2020-07-20 04:32:28.641616  HistoricalRequestProcessor: finishedRequest:  46
# Progress:  0.36
# Running Request:  82
# 2020-07-20 04:32:34.576496  HistoricalRequestProcessor: finishedRequest:  74
# Progress:  0.36444444444444446
# Running Request:  83
# 2020-07-20 04:32:34.580974  HistoricalRequestProcessor: finishedRequest:  47
# Progress:  0.3688888888888889
# Running Request:  84
# 2020-07-20 04:32:34.594955  HistoricalRequestProcessor: finishedRequest:  70
# Progress:  0.37333333333333335
# Running Request:  85
# 2020-07-20 04:32:34.600284  HistoricalRequestProcessor: finishedRequest:  67
# Progress:  0.37777777777777777
# Running Request:  86
# 2020-07-20 04:32:40.581599  HistoricalRequestProcessor: finishedRequest:  65
# Progress:  0.38222222222222224
# Running Request:  87
# 2020-07-20 04:32:40.593782  HistoricalRequestProcessor: finishedRequest:  82
# Progress:  0.38666666666666666
# Running Request:  88
# 2020-07-20 04:32:40.601149  HistoricalRequestProcessor: finishedRequest:  80
# Progress:  0.39111111111111113
# Running Request:  89
# 2020-07-20 04:32:40.609160  HistoricalRequestProcessor: finishedRequest:  22
# Progress:  0.39555555555555555
# Running Request:  90
# 2020-07-20 04:32:46.615548  HistoricalRequestProcessor: finishedRequest:  84
# Progress:  0.4
# Running Request:  91
# 2020-07-20 04:32:46.618768  HistoricalRequestProcessor: finishedRequest:  0
# Progress:  0.40444444444444444
# Running Request:  92
# 2020-07-20 04:32:46.622238  HistoricalRequestProcessor: finishedRequest:  85
# Progress:  0.4088888888888889
# Running Request:  93
# 2020-07-20 04:32:52.593795  HistoricalRequestProcessor: finishedRequest:  53
# Progress:  0.41333333333333333
# Running Request:  94
# 2020-07-20 04:32:52.597625  HistoricalRequestProcessor: finishedRequest:  44
# Progress:  0.4177777777777778
# Running Request:  95
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# WARNING:  Market data farm connection is broken:usfarm.nj
# 2020-07-20 04:32:58.605881  HistoricalRequestProcessor: finishedRequest:  86
# Progress:  0.4222222222222222
# Running Request:  96
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# WARNING:  Market data farm connection is OK:usfarm.nj
# 2020-07-20 04:33:04.574043  HistoricalRequestProcessor: finishedRequest:  8
# Progress:  0.4266666666666667
# Running Request:  97
# 2020-07-20 04:33:10.670610  HistoricalRequestProcessor: finishedRequest:  78
# Progress:  0.4311111111111111
# Running Request:  98
# 2020-07-20 04:33:16.613531  HistoricalRequestProcessor: finishedRequest:  92
# Progress:  0.43555555555555553
# Running Request:  99
# 2020-07-20 04:33:28.585204  HistoricalRequestProcessor: finishedRequest:  51
# Progress:  0.44
# Running Request:  100
# 2020-07-20 04:33:28.590891  HistoricalRequestProcessor: finishedRequest:  18
# Progress:  0.4444444444444444
# Running Request:  101
# 2020-07-20 04:33:28.596094  HistoricalRequestProcessor: finishedRequest:  75
# Progress:  0.4488888888888889
# Running Request:  102
# 2020-07-20 04:33:28.606764  HistoricalRequestProcessor: finishedRequest:  95
# Progress:  0.4533333333333333
# Running Request:  103
# 2020-07-20 04:33:28.610303  HistoricalRequestProcessor: finishedRequest:  83
# Progress:  0.4577777777777778
# Running Request:  104
# 2020-07-20 04:33:28.618267  HistoricalRequestProcessor: finishedRequest:  91
# Progress:  0.4622222222222222
# Running Request:  105
# 2020-07-20 04:33:28.622051  HistoricalRequestProcessor: finishedRequest:  55
# Progress:  0.4666666666666667
# Running Request:  106
# 2020-07-20 04:33:28.634294  HistoricalRequestProcessor: finishedRequest:  76
# Progress:  0.4711111111111111
# Running Request:  107
# 2020-07-20 04:33:34.623699  HistoricalRequestProcessor: finishedRequest:  79
# Progress:  0.47555555555555556
# Running Request:  108
# 2020-07-20 04:33:34.628006  HistoricalRequestProcessor: finishedRequest:  77
# Progress:  0.48
# Running Request:  109
# 2020-07-20 04:33:34.630091  HistoricalRequestProcessor: finishedRequest:  94
# Progress:  0.48444444444444446
# Running Request:  110
# 2020-07-20 04:33:34.633330  HistoricalRequestProcessor: finishedRequest:  50
# Progress:  0.4888888888888889
# Running Request:  111
# 2020-07-20 04:33:40.582188  HistoricalRequestProcessor: finishedRequest:  101
# Progress:  0.49333333333333335
# Running Request:  112
# 2020-07-20 04:33:40.586071  HistoricalRequestProcessor: finishedRequest:  19
# Progress:  0.49777777777777776
# Running Request:  113
# 2020-07-20 04:33:40.599254  HistoricalRequestProcessor: finishedRequest:  107
# Progress:  0.5022222222222222
# Running Request:  114
# 2020-07-20 04:33:40.602355  HistoricalRequestProcessor: finishedRequest:  40
# Progress:  0.5066666666666667
# Running Request:  115
# 2020-07-20 04:33:46.575472  HistoricalRequestProcessor: finishedRequest:  102
# Progress:  0.5111111111111111
# Running Request:  116
# 2020-07-20 04:33:46.590825  HistoricalRequestProcessor: finishedRequest:  97
# Progress:  0.5155555555555555
# Running Request:  117
# 2020-07-20 04:33:46.594112  HistoricalRequestProcessor: finishedRequest:  23
# Progress:  0.52
# Running Request:  118
# 2020-07-20 04:33:52.666864  HistoricalRequestProcessor: finishedRequest:  106
# Progress:  0.5244444444444445
# Running Request:  119
# 2020-07-20 04:33:52.669560  HistoricalRequestProcessor: finishedRequest:  104
# Progress:  0.5288888888888889
# Running Request:  120
# 2020-07-20 04:33:58.605304  HistoricalRequestProcessor: finishedRequest:  118
# Progress:  0.5333333333333333
# Running Request:  121
# 2020-07-20 04:34:04.628556  HistoricalRequestProcessor: finishedRequest:  116
# Progress:  0.5377777777777778
# Running Request:  122
# 2020-07-20 04:34:10.568804  HistoricalRequestProcessor: finishedRequest:  105
# Progress:  0.5422222222222223
# Running Request:  123
# 2020-07-20 04:34:16.623919  HistoricalRequestProcessor: finishedRequest:  119
# Progress:  0.5466666666666666
# Running Request:  124
# 2020-07-20 04:34:28.594089  HistoricalRequestProcessor: finishedRequest:  120
# Progress:  0.5511111111111111
# Running Request:  125
# 2020-07-20 04:34:28.597648  HistoricalRequestProcessor: finishedRequest:  21
# Progress:  0.5555555555555556
# Running Request:  126
# 2020-07-20 04:34:28.603583  HistoricalRequestProcessor: finishedRequest:  121
# Progress:  0.56
# Running Request:  127
# 2020-07-20 04:34:28.607358  HistoricalRequestProcessor: finishedRequest:  112
# Progress:  0.5644444444444444
# Running Request:  128
# 2020-07-20 04:34:28.621276  HistoricalRequestProcessor: finishedRequest:  122
# Progress:  0.5688888888888889
# Running Request:  129
# 2020-07-20 04:34:28.624924  HistoricalRequestProcessor: finishedRequest:  7
# Progress:  0.5733333333333334
# Running Request:  130
# 2020-07-20 04:34:28.637815  HistoricalRequestProcessor: finishedRequest:  100
# Progress:  0.5777777777777777
# Running Request:  131
# 2020-07-20 04:34:28.640666  HistoricalRequestProcessor: finishedRequest:  73
# Progress:  0.5822222222222222
# Running Request:  132
# 2020-07-20 04:34:34.631864  HistoricalRequestProcessor: finishedRequest:  123
# Progress:  0.5866666666666667
# Running Request:  133
# 2020-07-20 04:34:34.635602  HistoricalRequestProcessor: finishedRequest:  103
# Progress:  0.5911111111111111
# Running Request:  134
# 2020-07-20 04:34:34.639349  HistoricalRequestProcessor: finishedRequest:  109
# Progress:  0.5955555555555555
# Running Request:  135
# 2020-07-20 04:34:34.642427  HistoricalRequestProcessor: finishedRequest:  1
# Progress:  0.6
# Running Request:  136
# 2020-07-20 04:34:40.822238  HistoricalRequestProcessor: finishedRequest:  117
# Progress:  0.6044444444444445
# Running Request:  137
# 2020-07-20 04:34:40.826252  HistoricalRequestProcessor: finishedRequest:  129
# Progress:  0.6088888888888889
# Running Request:  138
# 2020-07-20 04:34:40.829404  HistoricalRequestProcessor: finishedRequest:  131
# Progress:  0.6133333333333333
# Running Request:  139
# 2020-07-20 04:34:40.833263  HistoricalRequestProcessor: finishedRequest:  130
# Progress:  0.6177777777777778
# Running Request:  140
# 2020-07-20 04:34:46.594250  HistoricalRequestProcessor: finishedRequest:  128
# Progress:  0.6222222222222222
# Running Request:  141
# 2020-07-20 04:34:46.598076  HistoricalRequestProcessor: finishedRequest:  25
# Progress:  0.6266666666666667
# Running Request:  142
# 2020-07-20 04:34:46.607408  HistoricalRequestProcessor: finishedRequest:  133
# Progress:  0.6311111111111111
# Running Request:  143
# 2020-07-20 04:34:52.599720  HistoricalRequestProcessor: finishedRequest:  137
# Progress:  0.6355555555555555
# Running Request:  144
# 2020-07-20 04:34:52.603008  HistoricalRequestProcessor: finishedRequest:  140
# Progress:  0.64
# Running Request:  145
# 2020-07-20 04:34:58.608599  HistoricalRequestProcessor: finishedRequest:  142
# Progress:  0.6444444444444445
# Running Request:  146
# 2020-07-20 04:35:04.581295  HistoricalRequestProcessor: finishedRequest:  145
# Progress:  0.6488888888888888
# Running Request:  147
# 2020-07-20 04:35:10.686379  HistoricalRequestProcessor: finishedRequest:  16
# Progress:  0.6533333333333333
# Running Request:  148
# 2020-07-20 04:35:16.581777  HistoricalRequestProcessor: finishedRequest:  138
# Progress:  0.6577777777777778
# Running Request:  149
# 2020-07-20 04:35:28.626168  HistoricalRequestProcessor: finishedRequest:  144
# Progress:  0.6622222222222223
# Running Request:  150
# 2020-07-20 04:35:28.630007  HistoricalRequestProcessor: finishedRequest:  135
# Progress:  0.6666666666666666
# Running Request:  151
# 2020-07-20 04:35:28.633327  HistoricalRequestProcessor: finishedRequest:  87
# Progress:  0.6711111111111111
# Running Request:  152
# 2020-07-20 04:35:28.637320  HistoricalRequestProcessor: finishedRequest:  111
# Progress:  0.6755555555555556
# Running Request:  153
# 2020-07-20 04:35:28.640346  HistoricalRequestProcessor: finishedRequest:  39
# Progress:  0.68
# Running Request:  154
# 2020-07-20 04:35:28.643831  HistoricalRequestProcessor: finishedRequest:  99
# Progress:  0.6844444444444444
# Running Request:  155
# 2020-07-20 04:35:34.564690  HistoricalRequestProcessor: finishedRequest:  108
# Progress:  0.6888888888888889
# Running Request:  156
# 2020-07-20 04:35:40.576266  HistoricalRequestProcessor: finishedRequest:  153
# Progress:  0.6933333333333334
# Running Request:  157
# 2020-07-20 04:35:40.580223  HistoricalRequestProcessor: finishedRequest:  126
# Progress:  0.6977777777777778
# Running Request:  158
# 2020-07-20 04:35:46.579387  HistoricalRequestProcessor: finishedRequest:  156
# Progress:  0.7022222222222222
# Running Request:  159
# 2020-07-20 04:36:28.592839  HistoricalRequestProcessor: finishedRequest:  141
# Progress:  0.7066666666666667
# Running Request:  160
# 2020-07-20 04:36:28.597390  HistoricalRequestProcessor: finishedRequest:  9
# Progress:  0.7111111111111111
# Running Request:  161
# 2020-07-20 04:36:28.602519  HistoricalRequestProcessor: finishedRequest:  42
# Progress:  0.7155555555555555
# Running Request:  162
# 2020-07-20 04:36:28.605548  HistoricalRequestProcessor: finishedRequest:  81
# Progress:  0.72
# Running Request:  163
# 2020-07-20 04:36:28.811582  HistoricalRequestProcessor: finishedRequest:  110
# Progress:  0.7244444444444444
# Running Request:  164
# 2020-07-20 04:36:28.887474  HistoricalRequestProcessor: finishedRequest:  134
# Progress:  0.7288888888888889
# Running Request:  165
# 2020-07-20 04:36:28.916264  HistoricalRequestProcessor: finishedRequest:  149
# Progress:  0.7333333333333333
# Running Request:  166
# 2020-07-20 04:36:28.924221  HistoricalRequestProcessor: finishedRequest:  143
# Progress:  0.7377777777777778
# Running Request:  167
# 2020-07-20 04:36:28.934437  HistoricalRequestProcessor: finishedRequest:  127
# Progress:  0.7422222222222222
# Running Request:  168
# 2020-07-20 04:36:28.939983  HistoricalRequestProcessor: finishedRequest:  146
# Progress:  0.7466666666666667
# Running Request:  169
# 2020-07-20 04:36:28.952047  HistoricalRequestProcessor: finishedRequest:  154
# Progress:  0.7511111111111111
# Running Request:  170
# 2020-07-20 04:36:28.986943  HistoricalRequestProcessor: finishedRequest:  136
# Progress:  0.7555555555555555
# Running Request:  171
# 2020-07-20 04:36:28.988661  HistoricalRequestProcessor: finishedRequest:  125
# Progress:  0.76
# Running Request:  172
# 2020-07-20 04:36:28.992311  HistoricalRequestProcessor: finishedRequest:  157
# Progress:  0.7644444444444445
# Running Request:  173
# 2020-07-20 04:36:28.995874  HistoricalRequestProcessor: finishedRequest:  11
# Progress:  0.7688888888888888
# Running Request:  174
# 2020-07-20 04:36:29.044323  HistoricalRequestProcessor: finishedRequest:  155
# Progress:  0.7733333333333333
# Running Request:  175
# 2020-07-20 04:36:29.054517  HistoricalRequestProcessor: finishedRequest:  158
# Progress:  0.7777777777777778
# Running Request:  176
# 2020-07-20 04:36:29.058712  HistoricalRequestProcessor: finishedRequest:  148
# Progress:  0.7822222222222223
# Running Request:  177
# 2020-07-20 04:36:29.062872  HistoricalRequestProcessor: finishedRequest:  152
# Progress:  0.7866666666666666
# Running Request:  178
# 2020-07-20 04:36:29.066534  HistoricalRequestProcessor: finishedRequest:  20
# Progress:  0.7911111111111111
# Running Request:  179
# 2020-07-20 04:36:29.070465  HistoricalRequestProcessor: finishedRequest:  28
# Progress:  0.7955555555555556
# Running Request:  180
# 2020-07-20 04:36:29.073535  HistoricalRequestProcessor: finishedRequest:  52
# Progress:  0.8
# Running Request:  181
# 2020-07-20 04:36:29.077871  HistoricalRequestProcessor: finishedRequest:  5
# Progress:  0.8044444444444444
# Running Request:  182
# 2020-07-20 04:36:34.567986  HistoricalRequestProcessor: finishedRequest:  150
# Progress:  0.8088888888888889
# Running Request:  183
# 2020-07-20 04:36:34.570582  HistoricalRequestProcessor: finishedRequest:  147
# Progress:  0.8133333333333334
# Running Request:  184
# 2020-07-20 04:36:34.574329  HistoricalRequestProcessor: finishedRequest:  12
# Progress:  0.8177777777777778
# Running Request:  185
# 2020-07-20 04:36:34.579479  HistoricalRequestProcessor: finishedRequest:  26
# Progress:  0.8222222222222222
# Running Request:  186
# 2020-07-20 04:36:40.726231  HistoricalRequestProcessor: finishedRequest:  168
# Progress:  0.8266666666666667
# Running Request:  187
# 2020-07-20 04:36:40.729519  HistoricalRequestProcessor: finishedRequest:  178
# Progress:  0.8311111111111111
# Running Request:  188
# 2020-07-20 04:36:40.733218  HistoricalRequestProcessor: finishedRequest:  175
# Progress:  0.8355555555555556
# Running Request:  189
# 2020-07-20 04:36:40.736427  HistoricalRequestProcessor: finishedRequest:  176
# Progress:  0.84
# Running Request:  190
# 2020-07-20 04:36:46.581548  HistoricalRequestProcessor: finishedRequest:  171
# Progress:  0.8444444444444444
# Running Request:  191
# 2020-07-20 04:36:46.585173  HistoricalRequestProcessor: finishedRequest:  180
# Progress:  0.8488888888888889
# Running Request:  192
# 2020-07-20 04:36:46.597217  HistoricalRequestProcessor: finishedRequest:  170
# Progress:  0.8533333333333334
# Running Request:  193
# 2020-07-20 04:36:52.688401  HistoricalRequestProcessor: finishedRequest:  188
# Progress:  0.8577777777777778
# Running Request:  194
# 2020-07-20 04:36:52.691945  HistoricalRequestProcessor: finishedRequest:  173
# Progress:  0.8622222222222222
# Running Request:  195
# 2020-07-20 04:36:58.633288  HistoricalRequestProcessor: finishedRequest:  191
# Progress:  0.8666666666666667
# Running Request:  196
# 2020-07-20 04:37:04.569749  HistoricalRequestProcessor: finishedRequest:  174
# Progress:  0.8711111111111111
# Running Request:  197
# 2020-07-20 04:37:10.589784  HistoricalRequestProcessor: finishedRequest:  182
# Progress:  0.8755555555555555
# Running Request:  198
# 2020-07-20 04:37:16.582511  HistoricalRequestProcessor: finishedRequest:  192
# Progress:  0.88
# Running Request:  199
# 2020-07-20 04:37:28.637948  HistoricalRequestProcessor: finishedRequest:  90
# Progress:  0.8844444444444445
# Running Request:  200
# 2020-07-20 04:37:28.640890  HistoricalRequestProcessor: finishedRequest:  165
# Progress:  0.8888888888888888
# Running Request:  201
# 2020-07-20 04:37:28.643900  HistoricalRequestProcessor: finishedRequest:  193
# Progress:  0.8933333333333333
# Running Request:  202
# 2020-07-20 04:37:28.646795  HistoricalRequestProcessor: finishedRequest:  196
# Progress:  0.8977777777777778
# Running Request:  203
# 2020-07-20 04:37:28.649740  HistoricalRequestProcessor: finishedRequest:  179
# Progress:  0.9022222222222223
# Running Request:  204
# 2020-07-20 04:37:28.653363  HistoricalRequestProcessor: finishedRequest:  169
# Progress:  0.9066666666666666
# Running Request:  205
# 2020-07-20 04:37:28.655986  HistoricalRequestProcessor: finishedRequest:  160
# Progress:  0.9111111111111111
# Running Request:  206
# 2020-07-20 04:37:28.658473  HistoricalRequestProcessor: finishedRequest:  187
# Progress:  0.9155555555555556
# Running Request:  207
# 2020-07-20 04:37:34.572229  HistoricalRequestProcessor: finishedRequest:  198
# Progress:  0.92
# Running Request:  208
# 2020-07-20 04:37:34.585371  HistoricalRequestProcessor: finishedRequest:  197
# Progress:  0.9244444444444444
# Running Request:  209
# 2020-07-20 04:37:34.589404  HistoricalRequestProcessor: finishedRequest:  199
# Progress:  0.9288888888888889
# Running Request:  210
# 2020-07-20 04:37:34.600988  HistoricalRequestProcessor: finishedRequest:  194
# Progress:  0.9333333333333333
# Running Request:  211
# 2020-07-20 04:37:40.593190  HistoricalRequestProcessor: finishedRequest:  206
# Progress:  0.9377777777777778
# Running Request:  212
# 2020-07-20 04:37:40.596490  HistoricalRequestProcessor: finishedRequest:  205
# Progress:  0.9422222222222222
# Running Request:  213
# 2020-07-20 04:37:40.606133  HistoricalRequestProcessor: finishedRequest:  89
# Progress:  0.9466666666666667
# Running Request:  214
# 2020-07-20 04:37:40.609242  HistoricalRequestProcessor: finishedRequest:  203
# Progress:  0.9511111111111111
# Running Request:  215
# 2020-07-20 04:37:46.585536  HistoricalRequestProcessor: finishedRequest:  210
# Progress:  0.9555555555555556
# Running Request:  216
# 2020-07-20 04:37:46.588794  HistoricalRequestProcessor: finishedRequest:  189
# Progress:  0.96
# Running Request:  217
# 2020-07-20 04:37:46.598538  HistoricalRequestProcessor: finishedRequest:  209
# Progress:  0.9644444444444444
# Running Request:  218
# 2020-07-20 04:37:52.607498  HistoricalRequestProcessor: finishedRequest:  214
# Progress:  0.9688888888888889
# Running Request:  219
# 2020-07-20 04:37:52.611695  HistoricalRequestProcessor: finishedRequest:  211
# Progress:  0.9733333333333334
# Running Request:  220
# 2020-07-20 04:37:58.614856  HistoricalRequestProcessor: finishedRequest:  217
# Progress:  0.9777777777777777
# Running Request:  221
# 2020-07-20 04:38:04.585714  HistoricalRequestProcessor: finishedRequest:  218
# Progress:  0.9822222222222222
# Running Request:  222
# 2020-07-20 04:38:10.602472  HistoricalRequestProcessor: finishedRequest:  215
# Progress:  0.9866666666666667
# Running Request:  223
# 2020-07-20 04:38:16.651187  HistoricalRequestProcessor: finishedRequest:  220
# Progress:  0.9911111111111112
# Running Request:  224
# 2020-07-20 04:38:28.596937  HistoricalRequestProcessor: finishedRequest:  207
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.598847 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.599871  HistoricalRequestProcessor: finishedRequest:  213
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.601298 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.602262  HistoricalRequestProcessor: finishedRequest:  183
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.603674 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.610144  HistoricalRequestProcessor: finishedRequest:  208
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.611851 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.612534  HistoricalRequestProcessor: finishedRequest:  167
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.613896 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.628056  HistoricalRequestProcessor: finishedRequest:  223
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.630112 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.630648  HistoricalRequestProcessor: finishedRequest:  172
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.630750 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:28.645154  HistoricalRequestProcessor: finishedRequest:  202
# Progress:  0.9955555555555555
# 2020-07-20 04:38:28.645308 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:34.571301  HistoricalRequestProcessor: finishedRequest:  216
# Progress:  0.9955555555555555
# 2020-07-20 04:38:34.571557 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:34.574458  HistoricalRequestProcessor: finishedRequest:  204
# Progress:  0.9955555555555555
# 2020-07-20 04:38:34.574639 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:34.586050  HistoricalRequestProcessor: finishedRequest:  224
# Progress:  0.9955555555555555
# 2020-07-20 04:38:34.586366 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:34.588112  HistoricalRequestProcessor: finishedRequest:  221
# Progress:  0.9955555555555555
# 2020-07-20 04:38:34.588246 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:40.580888  HistoricalRequestProcessor: finishedRequest:  219
# Progress:  0.9955555555555555
# 2020-07-20 04:38:40.581165 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:40.586615  HistoricalRequestProcessor: finishedRequest:  186
# Progress:  0.9955555555555555
# 2020-07-20 04:38:40.586869 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:40.588920  HistoricalRequestProcessor: finishedRequest:  201
# Progress:  0.9955555555555555
# 2020-07-20 04:38:40.589122 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:40.592677  HistoricalRequestProcessor: finishedRequest:  185
# Progress:  0.9955555555555555
# 2020-07-20 04:38:40.592867 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:46.584571  HistoricalRequestProcessor: finishedRequest:  93
# Progress:  0.9955555555555555
# 2020-07-20 04:38:46.584817 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:46.600452  HistoricalRequestProcessor: finishedRequest:  212
# Progress:  0.9955555555555555
# 2020-07-20 04:38:46.600642 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:46.602299  HistoricalRequestProcessor: finishedRequest:  151
# Progress:  0.9955555555555555
# 2020-07-20 04:38:46.602425 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:52.592584  HistoricalRequestProcessor: finishedRequest:  132
# Progress:  0.9955555555555555
# 2020-07-20 04:38:52.594297 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:52.607875  HistoricalRequestProcessor: finishedRequest:  200
# Progress:  0.9955555555555555
# 2020-07-20 04:38:52.609032 HistoricalRequestProcessor: completion
# 2020-07-20 04:38:58.648621  HistoricalRequestProcessor: finishedRequest:  159
# Progress:  0.9955555555555555
# 2020-07-20 04:38:58.650698 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:04.664246  HistoricalRequestProcessor: finishedRequest:  56
# Progress:  0.9955555555555555
# 2020-07-20 04:39:04.665859 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:10.598182  HistoricalRequestProcessor: finishedRequest:  164
# Progress:  0.9955555555555555
# 2020-07-20 04:39:10.599975 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:16.600575  HistoricalRequestProcessor: finishedRequest:  166
# Progress:  0.9955555555555555
# 2020-07-20 04:39:16.602950 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.599007  HistoricalRequestProcessor: finishedRequest:  54
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.601214 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.602613  HistoricalRequestProcessor: finishedRequest:  57
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.604243 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.612180  HistoricalRequestProcessor: finishedRequest:  184
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.613618 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.615737  HistoricalRequestProcessor: finishedRequest:  98
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.617214 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.629373  HistoricalRequestProcessor: finishedRequest:  62
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.631192 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.632405  HistoricalRequestProcessor: finishedRequest:  64
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.633850 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.645317  HistoricalRequestProcessor: finishedRequest:  113
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.645665 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:28.649643  HistoricalRequestProcessor: finishedRequest:  10
# Progress:  0.9955555555555555
# 2020-07-20 04:39:28.649811 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:34.573259  HistoricalRequestProcessor: finishedRequest:  96
# Progress:  0.9955555555555555
# 2020-07-20 04:39:34.575041 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:34.576507  HistoricalRequestProcessor: finishedRequest:  114
# Progress:  0.9955555555555555
# 2020-07-20 04:39:34.578641 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:34.598036  HistoricalRequestProcessor: finishedRequest:  124
# Progress:  0.9955555555555555
# 2020-07-20 04:39:34.600132 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:34.601329  HistoricalRequestProcessor: finishedRequest:  115
# Progress:  0.9955555555555555
# 2020-07-20 04:39:34.603085 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:40.588757  HistoricalRequestProcessor: finishedRequest:  222
# Progress:  0.9955555555555555
# 2020-07-20 04:39:40.590874 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:40.591671  HistoricalRequestProcessor: finishedRequest:  177
# Progress:  0.9955555555555555
# 2020-07-20 04:39:40.593064 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:40.598499  HistoricalRequestProcessor: finishedRequest:  163
# Progress:  0.9955555555555555
# 2020-07-20 04:39:40.600362 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:40.601136  HistoricalRequestProcessor: finishedRequest:  161
# Progress:  0.9955555555555555
# 2020-07-20 04:39:40.602718 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:46.763503  HistoricalRequestProcessor: finishedRequest:  195
# Progress:  0.9955555555555555
# 2020-07-20 04:39:46.765773 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:46.766568  HistoricalRequestProcessor: finishedRequest:  88
# Progress:  0.9955555555555555
# 2020-07-20 04:39:46.768410 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:46.769204  HistoricalRequestProcessor: finishedRequest:  190
# Progress:  0.9955555555555555
# 2020-07-20 04:39:46.770523 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:52.591736  HistoricalRequestProcessor: finishedRequest:  36
# Progress:  0.9955555555555555
# 2020-07-20 04:39:52.593411 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:52.609434  HistoricalRequestProcessor: finishedRequest:  61
# Progress:  0.9955555555555555
# 2020-07-20 04:39:52.611040 HistoricalRequestProcessor: completion
# 2020-07-20 04:39:58.659105  HistoricalRequestProcessor: finishedRequest:  162
# Progress:  0.9955555555555555
# 2020-07-20 04:39:58.661160 HistoricalRequestProcessor: completion
# 2020-07-20 04:40:04.588789  HistoricalRequestProcessor: finishedRequest:  181
# Progress:  0.9955555555555555
# 2020-07-20 04:40:04.590661 HistoricalRequestProcessor: completion
# 2020-07-20 04:40:10.616874  HistoricalRequestProcessor: finishedRequest:  139
# Progress:  0.9955555555555555
# 2020-07-20 04:40:10.618829 HistoricalRequestProcessor: completion
# 2020-07-20 04:40:16.674561  HistoricalRequestProcessor: finishedRequest:  49
# Progress:  0.9955555555555555
# 2020-07-20 04:40:16.676883 HistoricalRequestProcessor: completion
# unhandled exception in EReader thread
# Traceback (most recent call last):
#   File "/venv/lib/python3.6/site-packages/ibapi/reader.py", line 34, in run
#     data = self.conn.recvMsg()
#   File "/venv/lib/python3.6/site-packages/ibapi/connection.py", line 99, in recvMsg
#     buf = self._recvAllMsg()
#   File "/venv/lib/python3.6/site-packages/ibapi/connection.py", line 119, in _recvAllMsg
#     buf = self.socket.recv(4096)
# OSError: [Errno 9] Bad file descriptor

# %%
len(requestProcessor.reqIdDataMap) + requestProcessor.activeRequests + requestProcessor.failedRequests
# Out:
# 138

# %%
len(requestProcessor.reqIdDataMap)
# Out:
# 138

# %%
[i for i in range(len(requestProcessor.allReqsMap)) if i not in reqIds]
# Out:
# []

# %%
requestProcessor.activeRequests
# Out:
# -88

# %%
requestProcessor.allReqsMap[45]
# Out:
# {'reqId': 45,
#  'contract': 140339332077552: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#  'endDateStr': '20191118 23:59:59 PST',
#  'durationStr': '1 D',
#  'intervalStr': '4 hours',
#  'dataType': 'TRADES',
#  'useRTH': 0}

# %%
len(requestProcessor.reqIdDataMap)
# Out:
# 89

# %%
for reqId in requestProcessor.reqIdDataMap.keys():
    print(requestProcessor.allReqsMap[reqId])
# Out:
# {'reqId': 1, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191209 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 2, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191209 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 5, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191206 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 4, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191206 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 8, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191205 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 7, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191205 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 11, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191204 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 10, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191204 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 14, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191203 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 13, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191203 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 16, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191202 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 17, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191202 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 19, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191129 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 20, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191129 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 23, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191128 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 22, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191128 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 26, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191127 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 25, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191127 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 29, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191126 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 28, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191126 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 32, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191125 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 31, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191125 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 34, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191122 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 35, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191122 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 38, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191121 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 37, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191121 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 41, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191120 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 40, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191120 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 44, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191119 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 43, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191119 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 47, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191118 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'HISTORICAL_VOLATILITY', 'useRTH': 0}
# {'reqId': 46, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191118 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}
# {'reqId': 49, 'contract': 140339334337872: 0,SPY,STK,,0.0,,,NYSE,,USD,,,False,,combo:, 'endDateStr': '20191115 23:59:59 PST', 'durationStr': '1 D', 'intervalStr': '4 hours', 'dataType': 'OPTION_IMPLIED_VOLATILITY', 'useRTH': 0}

# %%
contract = Contract()
contract.symbol = "SPY"
contract.secType = "STK"
contract.exchange = "SMART"
contract.currency = "USD"

getDayEquityInfo(contract, day, True)

# %%
aggregation_periods = ["1min", "5min", "15min", "30min", "1hr", "4hr", "1day", "2day", "3day", "4day", "5day", "10day", "15day", "20day", "25day"]

# Next 

# windows of and find the lowest points and start to find trends until the trend with 
# define min_window per aggregation period
# max_window of aggregation period

# Lows on the RSI
# Open and the close
# RSI Lows supports

# IV

# %%
len(reqIdScheduledDataMap)
# Out:
# 138

# %%
len(requestProcessor.non_granular_requests)
# Out:
# 138

# %%
len(requestProcessor.allReqsMap)
# Out:
# 138

# %%
l = [requestProcessor.allReqsMap[reqIdDataPair[0]] for reqIdDataPair in requestProcessor.reqIdDataMap.items() ] # if "20191025" in requestProcessor.allReqsMap[reqIdDataPair[1]]['date']] # if "20191025" in reqIdDataPair[1]["date"]]
l.sort(key=lambda x: x['endDateStr'])
l
# requestProcessor.allReqsMap[136]
#requestProcessor.non_granular_requests
# Out:
# [{'reqId': 133,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191008 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 128,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191010 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 120,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191014 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 122,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191014 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 121,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191014 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 118,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191015 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 114,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191016 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 116,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191016 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 115,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191016 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 112,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191017 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 113,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191017 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 108,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191018 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 110,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191018 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 109,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191018 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 105,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191021 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 107,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191021 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 104,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191022 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 102,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191022 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 103,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191022 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 101,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191023 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 96,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191024 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 98,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191024 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 94,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191025 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 95,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191025 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 91,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191028 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 92,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191028 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 88,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191029 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 87,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191029 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 89,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191029 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 86,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191030 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 84,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191030 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 85,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191030 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 82,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191031 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 78,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191101 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 79,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191101 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 75,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191104 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 74,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191105 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 69,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191106 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 68,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191107 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 66,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191107 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 63,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191108 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 61,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191111 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 60,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191111 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 59,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191112 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 54,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191113 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 55,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191113 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 51,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191114 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 52,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191114 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 53,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191114 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 49,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191115 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 45,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191118 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 44,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191119 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 43,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191119 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 42,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191119 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 41,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191120 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 39,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191120 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 40,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191120 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 37,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191121 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 34,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191122 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 28,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191126 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 29,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191126 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 27,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191126 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 24,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191127 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 25,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191127 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 26,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191127 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 23,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191128 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 22,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191128 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 21,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191128 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 18,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191129 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 20,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191129 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 19,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191129 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 17,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191202 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 16,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191202 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 15,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191202 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 14,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191203 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 13,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191203 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 12,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191203 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 9,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191204 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 10,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191204 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 11,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191204 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 6,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191205 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 7,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191205 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 8,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191205 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 4,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191206 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 5,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191206 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 3,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191206 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0},
#  {'reqId': 2,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191209 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'HISTORICAL_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 1,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191209 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'OPTION_IMPLIED_VOLATILITY',
#   'useRTH': 0},
#  {'reqId': 0,
#   'contract': 140339333576632: 0,SPY,STK,,0.0,,,SMART,,USD,,,False,,combo:,
#   'endDateStr': '20191209 23:59:59 PST',
#   'durationStr': '1 D',
#   'intervalStr': '4 hours',
#   'dataType': 'TRADES',
#   'useRTH': 0}]

# %%
tsv_dict = {}
for reqId, data in requestProcessor.reqIdDataMap.items():
    og_req = requestProcessor.allReqsMap[reqId]
    req_type = og_req["dataType"].lower()
    for row in data:
        dateObj = datetime.strptime(row["date"], "%Y%m%d %H:%M:%S")
        
        if dateObj not in tsv_dict:
            tsv_dict[dateObj] = {
                "time": row["date"]
            }
            
        tsv_dict[dateObj][req_type + "_open"] = row["open"]
        tsv_dict[dateObj][req_type + "_high"] = row["high"]
        tsv_dict[dateObj][req_type + "_low"] = row["low"]
        tsv_dict[dateObj][req_type + "_close"] = row["close"]
        tsv_dict[dateObj][req_type + "_volume"] = row["volume"]
        tsv_dict[dateObj][req_type + "_barCount"] = row["barCount"]
        tsv_dict[dateObj][req_type + "_average"] = row["average"]
        
spy_data_tsv = open("spy_043019_081219.tsv", "w")

columnTitles = ["time", 
                "trades_open", 
                "trades_high", 
                "trades_low", 
                "trades_close", 
                "trades_volume", 
                "trades_barCount", 
                "trades_average", 
                
                "option_implied_volatility_open", 
                "option_implied_volatility_high", 
                "option_implied_volatility_low", 
                "option_implied_volatility_close", 
                "option_implied_volatility_volume", 
                "option_implied_volatility_barCount", 
                "option_implied_volatility_average",
                
                "historical_volatility_open", 
                "historical_volatility_high", 
                "historical_volatility_low", 
                "historical_volatility_close", 
                "historical_volatility_volume", 
                "historical_volatility_barCount", 
                "historical_volatility_average",
               ]


    
spy_data_tsv.write("\t".join(columnTitles) + "\n")

for dateObjKey in sorted(tsv_dict.keys()):
    row = tsv_dict[dateObjKey]
    
    def transformedRow(title):
        val = row.get(title, "")
        if type(val) == int or type(val) == float:
            val = str(val)
        return val
    t_row = map(transformedRow, columnTitles)
    spy_data_tsv.write("\t".join(t_row) + "\n")
    
spy_data_tsv.close()

# %%
spy_data_tsv = open("spy_data.tsv", "w")

spy_data_tsv.write("\t".join(columnTitles) + "\n")

for dateObjKey in sorted(tsv_dict.keys()):
    row = tsv_dict[dateObjKey]
    
    def transformedRow(title):
        val = row.get(title, "")
        if type(val) == int or type(val) == float:
            val = str(val)
        return val
    t_row = map(transformedRow, columnTitles)
    spy_data_tsv.write("\t".join(t_row) + "\n")
    
spy_data_tsv.close()

# %%
import json

w_file = open("spydata.json", "w")
json.dump(requestProcessor.reqIdDataMap, w_file)
w_file.close()

# %%
og_gran_data = granular_deffered_req

# %%
# Goal: Disambuigate the following violation
# Making six or more historical data requests for the same Contract, Exchange and Tick Type within two seconds.
# og_gran_data

ten_same_datatype = list(og_gran_data)[:10]
five_diff_datatype = [d for i, d in enumerate(list(og_gran_data)) if i % 13 == 0]

ten_diff_datatype = list(five_diff_datatype)

for item in five_diff_datatype:
    modified_req = item.copy()
    modified_req["endDateStr"] = "20200514 " + modified_req["endDateStr"].split("20200515")[1]
    ten_diff_datatype.append(modified_req)

# %%
granular_deffered_req = ten_diff_datatype
deffered_req = []
processRequests()

# %%
def processGranularRequests():
    startIdx = 0
    lastIdx = len(granular_deffered_req)
    
    def run_first50_batch():
        nonlocal startIdx
        def run_last10_batch():
            nonlocal startIdx
            for i in range(startIdx, min(startIdx + 10, lastIdx)):
                req = granular_deffered_req[i]
                print("Running Granular Request: ", req["reqId"])

                ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
            
            if startIdx + 10 < lastIdx:     
                t = threading.Timer(granular_timeout, run_first50_batch)
                t.start()
            else:
                pass
                # Completion
        
        for i in range(startIdx, min(startIdx + 50, lastIdx)):
            req = granular_deffered_req[i]
            print("Running Granular Request: ", req["reqId"])

            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
        
        if startIdx + 50 < lastIdx:
            startIdx += 50
            t = threading.Timer(regular_timeout, run_last10_batch)
            t.start()
            
    run_first50_batch()

    
def processRequests():
    startIdx = 0
    lastIdx = len(deffered_req)
    
    def run_batch():
        nonlocal startIdx
        for i in range(startIdx, min(startIdx + 50, lastIdx)):
            req = deffered_req[i]
            print("Running Request: ", req["reqId"])

            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
        
        if startIdx + 50 < lastIdx:
            startIdx += 50
            t = threading.Timer(regular_timeout, run_batch)
            t.start()
        else:
            t = threading.Timer(regular_timeout, processGranularRequests)
            t.start()
            # Completion
        
    run_batch()

class HistoricalRequestProcessor():
    # TODO: Add granular limit logic
    # Data Limit requirements
    # No more than 50 historical data req open at the same time
    # No more than 50 calls per sec
    # Granular:
    # Identical hist req within 15sec (we shouldnt see this?)
    # Making 6+ hist req for same contract, exch, and Historical Data Types within 2 sec (is tick type Historical Data Types)
    # Making more that 60 req within 10 min
    MAX_ACTIVE_REQ = 50
    MAX_REQ_PER_SEC = 50
    def __init__(self):
        self.non_granular_requests = []
        self.granular_requests = []
        self.activeRequests = 0
        self.failedRequests = 0
        self.startIdx = 0
        self.currentRequestId
        self.reqIdDataMap = {}
        self.allReqsMap = {}
        
    def addGranularRequest(self, reqId, req):
        self.granular_requests.append(req)
        self.allReqsMap[reqId] = req
    
    def addRegularRequest(self, reqId, req):
        self.non_granular_requests.append(req)
        self.allReqsMap[reqId] = req
        
    def run_non_granular_batch(self):
        for i in range(self.startIdx, min(self.startIdx + 50, len(self.non_granular_requests))):
            req = self.non_granular_requests[i]
            print("Running Request: ", req["reqId"])
            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
            self.activeRequests += 1
        self.startIdx = min(self.startIdx + 50, len(self.non_granular_requests))
        
        if self.start == len(self.non_granular_requests):
            self.completion()
            
    def completion(self):
        print("HistoricalRequestProcessor: completion")
        ibapi.disconnect()
        
    def process(self):
        self.run_non_granular_batch() 
        
    def updateRequest(self, reqId, data):
        if reqId not in self.reqIdDataMap:
            self.reqIdDataMap[reqId] = []
        
        reqDT = self.allReqsMap[reqId]["dataType"]
#         if bar.date not in dataTypeDuplicateDateSetMap[reqDT]:
        self.reqIdDataMap[reqId].append({
            "date": bar.date,#datetime.strptime(bar.date, "%Y%m%d %H:%M:%S"),
            "open": bar.open,
            "high": bar.high,
            "low": bar.low,
            "close": bar.close,
            "volume": bar.volume,
            "barCount": bar.barCount,
            "average": bar.average,
        })
#             dataTypeDuplicateDateSetMap[reqDT].add(bar.date)
        
    def failedRequest(self, reqId, msg):
        print("HistoricalRequestProcessor: failedReqeust. ReqId: ", reqId, ": ", msg)
        self.failedRequests += 1
        if self.startIdx < len(self.non_granular_requests):
            self.startIdx += 1
            req = self.non_granular_requests[self.startIdx]
            print("Running Request: ", req["reqId"])
            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
        else:
            this.completion()
            
    def finishedRequest(reqId, barData):
        self.activeRequests -= 1
        print("HistoricalRequestProcessor: finishedRequest: ", reqId)
        if self.startIdx < len(self.non_granular_requests):
            self.startIdx += 1
            req = self.non_granular_requests[self.startIdx]
            print("Running Request: ", req["reqId"])
            ibapi.reqHistoricalData(req["reqId"], req["contract"], req["endDateStr"], req["durationStr"], req["intervalStr"], req["dataType"], req["useRTH"], 1, False, [])
        else:
            this.completion()

# %%
from datetime import datetime
from ibapi import wrapper
from ibapi import utils
from ibapi.client import EClient
from ibapi.utils import iswrapper
from ibapi.contract import *  
from ibapi.common import *
from ibapi.ticktype import * 

from app.wsgi import app
from app.extensions import db
from app.models.Equity import (
    Equity,
    EquityHistoricalData
)

# https://www.interactivebrokers.com/en/?f=%2Fen%2Fsoftware%2FsystemStatus.php

connectivityErrorCodes = [1100, 1300]
clientErrorCodes = [502, 504]
warningErrorCodes = [2100, 2137]
rateLimitErrorCodes = [100, 101]
twsErrorCodes = [102, 449]
twsErrorCodes2 = [10000, 10148]

contractReqIDDataMap = {}
isGranularmap = {}
tickersToFetch = []
failedRequests = 0
regular_timeout = 1.2


def determineEnd():
    if len(contractReqIDDataMap.keys()) == len(tickersToFetch) - failedRequests:
        updateEquitiesTable()
        ibapi.disconnect()

class IBContractDetailsCollector(wrapper.EWrapper):
    def contractDetails(self, reqId: int, contractDetails: ContractDetails):
        super().contractDetails(reqId, contractDetails)
        contractReqIDDataMap[reqId] = contractDetails
        

        determineEnd()
        
        
            
    def error(self, reqId: TickerId, errorCode: int, errorString: str):
        global failedRequests
        super().error(reqId, errorCode, errorString)
        
        if reqId == -1:
            if errorCode >= rateLimitErrorCodes[0] and errorCode <= rateLimitErrorCodes[1]:
                print("RATE LIMIT ERROR")
                # TODO: Hope it doesnt happen
            print("WARNING: ", errorString)
            return
        elif errorCode >= twsErrorCodes[0] and errorCode <= twsErrorCodes[1] or errorCode >= twsErrorCodes2[0] and errorCode <= twsErrorCodes2[1]:
            print("TWS ERROR: ", errorString)
            # Decrement Expected Results Count
            failedRequests += 1
            
        elif errorCode >= rateLimitErrorCodes[0] and errorCode <= rateLimitErrorCodes[1]:
            print("RATE LIMIT ERROR")
            
        determineEnd()
        
    def contractDetailsEnd(self, reqId: int):
        super().contractDetailsEnd(reqId)
        
    def nextValidId(self, reqId: int):
        super().nextValidId(reqId)
        print("Next Valid Id: ", reqId)
        loadEquitiesFromFile(open("scripts/equities.tsv"))

        
    def connectionClosed(self):
        super().connectionClosed()

def updateEquitiesTable():
    with app.app_context():
        for contract in contractReqIDDataMap.values():
            equity = Equity(
                name=contract.longName,
                ticker=contract.contract.symbol,
                ib_con_id=contract.contract.conId,
                should_update=isGranularmap[contract.contract.symbol]
            )
            db.session.add(equity)
        
        db.session.commit()

def processRequests():
    startIdx = 0
    lastIdx = len(scheduled_requests)
    
    def run_batch():
        nonlocal startIdx
        for i in range(startIdx, min(startIdx + 50, lastIdx)):
            req = scheduled_requests[i]
            print("Running Request: ", req["reqId"])

            ibapi.reqContractDetails(req["reqId"], req["contract"])
        
        if startIdx + 50 < lastIdx:
            startIdx += 50
            t = threading.Timer(regular_timeout, run_batch)
            t.start()
        
        
    run_batch()

scheduled_requests = []
def scheduleIBContractAPI(reqId, contract):
    def_req = {
        "reqId": reqId,
        "contract": contract,
    }
    scheduled_requests.append(def_req)

    
"""
file_obj: <ticker>\t<is_granular>
"""
def loadEquitiesFromFile(file_obj):
    global tickersToFetch

    lines = [x.strip().split("\t") for x in file_obj.readlines()]
    
    with app.app_context():
        didAnyEquityExist = False
        for line in lines:
            ticker = line[0]
            is_granular = int(line[1])
            
            equity = db.session.query(Equity).filter(Equity.ticker == ticker).first()
            
            if equity:
                didAnyEquityExist = True
                equity.granular = True if is_granular else False
                
            else:
                tickersToFetch.append(ticker)
                isGranularmap[ticker] = is_granular
                
        db.session.commit()
            
    curRequestId = 0
    for ticker in tickersToFetch:
        contract = Contract()
        contract.symbol = ticker
        contract.secType = "STK"
        contract.exchange = "SMART"
        contract.currency = "USD"
        
        scheduleIBContractAPI(curRequestId, contract)
        curRequestId += 1
        
    file_obj.close()
    processRequests()
    
        

contractDetailsCollector = IBContractDetailsCollector()   
ibapi = EClient(wrapper=contractDetailsCollector)
gatewayPort = 4001
twsPort = 7496
ibapi.connect("host.docker.internal", gatewayPort, clientId=0)
ibapi.run()

# %%
with app.app_context():
    print(db.session.query(Equity).filter(Equity.ticker == "GOOGL").first().ib_con_id)

# %%
from threading import Thread

options_strikes = None
options_exp = None

class IBHistoricalDataAggregator(wrapper.EWrapper):
    
    def historicalData(self, reqId:int, bar: BarData):
        super().historicalData(reqId, bar)
        requestProcessor.updateRequest(reqId, bar)
            
        
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        requestProcessor.finishedRequest(reqId)
        
    def error(self, reqId: TickerId, errorCode: int, errorString: str):
        global failedRequests
        global failed_options_req
        super().error(reqId, errorCode, errorString)
        
        if reqId == -1:
            if errorCode >= rateLimitErrorCodes[0] and errorCode <= rateLimitErrorCodes[1]:
                print("RATE LIMIT ERROR")
                # TODO: Hope it doesnt happen
            print("WARNING: ", errorString)
            return
        elif errorCode >= twsErrorCodes[0] and errorCode <= twsErrorCodes[1] or errorCode >= twsErrorCodes2[0] and errorCode <= twsErrorCodes2[1]:
            print("TWS ERROR: ", errorString)
            # Decrement Expected Results Count
            if reqId > len(optionsReqIdScheduledDataMap.keys()):
                requestProcessor.failedRequest(reqId, errorString)
#                 failedRequests += 1
            else:  
                failed_options_req += 1
            
        elif errorCode >= rateLimitErrorCodes[0] and errorCode <= rateLimitErrorCodes[1]:
            print("RATE LIMIT ERROR")
            
    def securityDefinitionOptionParameter(self, reqId:int, exchange:str, underlyingConId:int, tradingClass:str, multiplier:str, expirations:SetOfString, strikes:SetOfFloat):
        super().securityDefinitionOptionParameter(reqId, exchange, underlyingConId, tradingClass, multiplier, expirations, strikes)
        global options_strikes
        global options_exp
        
        if exchange == "SMART":
            optionsReqDataMap[reqId] = {
                "expiration": expirations,
                "strike": strikes,                
            }
        else:
            failed_options_req += 1
            
        if len(optionsReqDataMap.keys()) == (len(optionsReqIdScheduledDataMap.keys()) - failed_options_req):
            # schedule options
            curReqId = len(reqIdScheduledDataMap.keys()) + len(optionsReqIdScheduledDataMap.keys())
            for key, val in optionsReqIdDataMap.items():
                for exp in val["expiration"]:
                    for strike in val["strike"]:     
                        pContract = Contract()
                        pContract.conId = optionsReqIdScheduledDataMap[key].conId
                        pContract.symbol = optionsReqIdScheduledDataMap[key].symbol
                        pContract.currency = optionsReqIdScheduledDataMap[key].currency
                        pContract.exchange = optionsReqIdScheduledDataMap[key].exchange
                        pContract.secType = "OPT"
                        pContract.lastTradeDateOrContractMonth = exp
                        pContract.strike = strike
                        pContract.right = "P"
                        
                        cContract = Contract()
                        cContract.conId = optionsReqIdScheduledDataMap[key].conId
                        cContract.symbol = optionsReqIdScheduledDataMap[key].symbol
                        cContract.currency = optionsReqIdScheduledDataMap[key].currency
                        cContract.exchange = optionsReqIdScheduledDataMap[key].exchange
                        cContract.secType = "OPT"
                        cContract.lastTradeDateOrContractMonth = exp
                        cContract.strike = strike
                        cContract.right = "C"
                        
                        for dataType in optionDataTypes:
                            scheduleIBHistoricalAPI(curReqId, cContract, endDateStr, "1 D", "1 min", dataType, 0)
                            curReqId += 1
                            scheduleIBHistoricalAPI(curReqId, pContract, endDateStr, "1 D", "1 min", dataType, 0)
                            curReqId += 1
                            
            # Start requesting
            processRequests()
        
    def nextValidId(self, reqId: int):
        super().nextValidId(reqId)
        print("Next Valid Id: ", reqId)
        
    def connectionClosed(self):
        super().connectionClosed()

class IBContractDetailsCollector(wrapper.EWrapper):
    def contractDetails(self, reqId: int, contractDetails: ContractDetails):
        super().contractDetails(reqId, contractDetails)
        contractReqIDDataMap[reqId] = contractDetails
        
        print("----Contract Details----")
        print("thread: ", threading.current_thread().name)
        print("reqID: ", reqId)
        print("company: ", contractDetails.longName)
        print("symbol: ", contractDetails.contract.symbol)
        print("tradingHours: ", contractDetails.tradingHours)
        print("liquidHours: ", contractDetails.liquidHours)

    def securityDefinitionOptionParameter(self, reqId:int, exchange:str, underlyingConId:int, tradingClass:str, multiplier:str, expirations:SetOfString, strikes:SetOfFloat):
        super().securityDefinitionOptionParameter(reqId, exchange, underlyingConId, tradingClass, multiplier, expirations, strikes)
        global options_strikes
        global options_exp
        print("----Option Chain Details----")
        print("exchange: ", exchange)
        print("underlyingConId: ", underlyingConId)
        print("tradingClass: ", tradingClass)
        print("multiplier: ", multiplier)
        print("expirations: ", expirations)
        print("strikes: ", strikes)
        
        if exchange == "SMART":
            options_exp = expirations
            options_strikes = strikes
        
    def contractDetailsEnd(self, reqId: int):
        super().contractDetailsEnd(reqId)
        
    def nextValidId(self, reqId: int):
        super().nextValidId(reqId)
        print("Next Valid Id: ", reqId)
        print("thread: ", threading.current_thread().name)
        
    def connectionClosed(self):
        super().connectionClosed()
        print("ConnectionClosed")

def 
        
        
class ThreadedIBApi(EClient, Thread):
    def __init__(self, wrapper):
        Thread.__init__(self)
        EClient.__init__(self, wrapper=wrapper)

contractDetailsCollector = IBContractDetailsCollector()   
ibapi = ThreadedIBApi(wrapper=contractDetailsCollector)
# ibapi2 = ThreadedIBApi(wrapper=contractDetailsCollector)
gatewayPort = 4001



ibapi.connect("host.docker.internal", gatewayPort, clientId=0)


ibapi.start()
